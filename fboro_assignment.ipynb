# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **FREDRICK ONWONG'A BORORIO**
# Aspiring Data Scientist

# %% [markdown]
# *I am studying this Data Science course as a pre-cursor to building on my data analytics skills to transform into a better data modeller and scientist, to tell stories through my data, build specialized machine learning models, and better predictive models.
# I am also keen on growing my portfolio beyond my job by adding it as an enviable skill.*

# %% [markdown]
# ### My code is expected to insert a new value to the end of a list

# %%
my_list = [15, 20, 25, 30, 35, 40]
my_list.append (45)
my_list
# Out:
# [15, 20, 25, 30, 35, 40, 45]

# %% [markdown]
# horizontal_rule is as shown below
# ***
# bulleted_list
#  - breakfast
#  - lunch
#  - supper
#  numbered_list
# 1. breakfast
# 2. lunch
# 3. supper
